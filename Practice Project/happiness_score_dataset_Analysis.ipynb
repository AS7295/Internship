# %% [markdown]
# # Happiness Score Dataset Analysis

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#load dataset
df=pd.read_csv("happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Dataset contains 158 rows and 12 columns

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# Hare we have notice the name of each columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# there are some basic information about this dataset. We have 158 no of rows indexing from 0 to 157. there are 12 columns present. count of non null value in each columns is 158 which indicates there are no missing value present in this dataset.As per requirement Happiness Score is the target variable and Economy (GDP per Capita), Family, Health (Life Expectancy), Freedom, Trust (Government Corruption), Generosity, Dystopia Residual are the input variavle. The data type of target variable is float64  which indicates that it is a continuous variable and this is a regression based problem.

# %%
# checking null value
print("Null Value :\n",df.isnull().sum())
sns.heatmap(df.isnull(), cmap='Blues')
plt.show()
# Out:
# Null Value :
#  Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# It shows that there is no missing value present in the dataset.

# %%
# setting index of Happiness Rank as this data is rank wise data as per Happiness Score
df.set_index('Happiness Rank', inplace=True)
df
# Out:
#                     Country                           Region  Happiness Score  \
# Happiness Rank
# 1               Switzerland                   Western Europe            7.587
# 2                   Iceland                   Western Europe            7.561
# 3                   Denmark                   Western Europe            7.527
# 4                    Norway                   Western Europe            7.522
# 5                    Canada                    North America            7.427
# ...                     ...                              ...              ...
# 154                  Rwanda               Sub-Saharan Africa            3.465
# 155                   Benin               Sub-Saharan Africa            3.340
# 156                   Syria  Middle East and Northern Africa            3.006
# 157                 Burundi               Sub-Saharan Africa            2.905
# 158                    Togo               Sub-Saharan Africa            2.839
#
# ...

# %%
#looking for no of unique value present in each column of the dataset.
df.nunique()
# Out:
# Country                          158
# Region                            10
# Happiness Score                  157
# Standard Error                   153
# Economy (GDP per Capita)         158
# Family                           158
# Health (Life Expectancy)         157
# Freedom                          158
# Trust (Government Corruption)    157
# Generosity                       158
# Dystopia Residual                158
# dtype: int64

# %% [markdown]
# Hare we found that mostly there are unique value present in tha dateset. despite of this there are 10 different region in the data set.

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: Country, Length: 158, dtype: int64
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: Happiness Score, Length: 157, dtype: int64
# 0.03780    2
# 0.03751    2
# 0.04394    2
# 0.05051    2
# 0.04934    2
#           ..
# 0.04114    1
# 0.04251    1
# ...

# %% [markdown]
# value counts columns shows the each unique value with its countings. hare also we can confirm that there are no missing value present in any column.

# %%
# Checking for descriptive data.
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# Observation:
# 1. count of each column is same which indicates that there is no missing value.
# 2. Difference of mean and median is comparetively very less. which indicates data is normally distributed.
# 3. difference between 75th percentile value and max value is not high as compared to the difference between 50th and 75th value in every column except standard error, Trust and Generosity column. which refers to the presence of outliers.

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Score', 'Standard Error',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# ## Univariate Analysis

# %%
sns.distplot(df['Economy (GDP per Capita)'], kde=True)
plt.show()

# %% [markdown]
# Kernel Density Estimation (kde) curve shows that the column 'Economy (GDP per Capita)' is normally distributed.

# %%
sns.lmplot(x='Economy (GDP per Capita)',y='Happiness Score',data=df)
plt.show()

# %%
sns.distplot(df['Family'],kde=True)
plt.show()

# %% [markdown]
# KDE curve shows that data is little bit skewed towards left.

# %%
sns.distplot(df['Health (Life Expectancy)'],kde=True)
plt.show()

# %% [markdown]
# kde curve shows that data is normally distributed and little bit skewed towards left.

# %%
sns.distplot(df['Freedom'], kde=True)
plt.show()

# %% [markdown]
# kde curve shows that all data is normally distributed.

# %%
sns.distplot(df['Trust (Government Corruption)'], kde=True)
plt.show()

# %% [markdown]
# kde curve shows that data is almost normally distributed and right skewed.

# %%
sns.distplot(df['Generosity'], kde=True)
plt.show()

# %% [markdown]
# kde curve shows that data is normally distributed.

# %%
sns.distplot(df['Dystopia Residual'], kde=True)
plt.show()

# %% [markdown]
# kde curve in Dystopia Residual shows that data is normally distributed.

# %% [markdown]
# ### Bivariate Analysis

# %%
#Chacking relation between happiness score and Economy (GDP per capita income)
sns.lmplot(data=df, x='Happiness Score', y='Economy (GDP per Capita)')
plt.show()

# %% [markdown]
# Happiness Score Vs Economy(GDP per capita) shows us that there is strong positive relation between economy and happiness score. where GDP per capita is high there happiness score is also high.

# %%
# Checking relation between Happiness Score and Family.
sns.lmplot(data=df, x='Happiness Score', y='Family')
plt.show()

# %% [markdown]
# In the plot Family vs Happiness Score there is a strong positive relation between them. Best fit regression line shows that Happiness Score increases with the incease in family.

# %%
# CHECKING relation between Happiness Score and Health (Life Expectancy)
sns.lmplot(data=df, x="Happiness Score", y='Health (Life Expectancy)')
plt.show()

# %% [markdown]
# There  is strong positive relation between Happiness Score and Health (life expectancy).

# %%
# Checking relation between Happiness Score and Fredom
sns.lmplot(data= df, x='Happiness Score', y= 'Freedom')
plt.show()

# %% [markdown]
# There is strong positive relation between Happiness Score and Freedom.

# %%
# Checking relation between Happiness Score and Trust (Government Corruption)
sns.lmplot(data=df, x='Happiness Score', y='Trust (Government Corruption)')
plt.show()

# %% [markdown]
# Stiffness of the best fit line is less which means there is not such positive relation between Trust (Government Corruption) and Happiness Score.

# %%
#Checking the relation between Happiness Score and Generosity
sns.lmplot(data=df, x='Happiness Score', y='Generosity')
plt.show()

# %% [markdown]
# The best fit regression line shows that the slope is less although it is positive. which means there is not such positive relation between Generosity and Happiness Score.

# %%
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# There is skewness present in Standard error , family Trust and Generocity column. so to remove skewness we need to apply boxcox method

# %%
from scipy.stats import boxcox
df['Standard Error']=boxcox(df['Standard Error'],0.5)
df['Family']=boxcox(df['Family'],0.5)
df['Trust (Government Corruption)']=boxcox(df['Trust (Government Corruption)'],0.5)
df['Generosity']=boxcox(df['Generosity'],0.5)
df.skew()
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.225889
# Economy (GDP per Capita)        -0.317575
# Family                          -2.193070
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    0.507663
# Generosity                      -0.130961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# somehow skewnees is still present in Standard error colum.

# %%
#Standard Error column is dropping out from the dataset
df.drop('Standard Error',axis=1,inplace=True)

# %%
df
# Out:
#                     Country                           Region  Happiness Score  \
# Happiness Rank
# 1               Switzerland                   Western Europe            7.587
# 2                   Iceland                   Western Europe            7.561
# 3                   Denmark                   Western Europe            7.527
# 4                    Norway                   Western Europe            7.522
# 5                    Canada                    North America            7.427
# ...                     ...                              ...              ...
# 154                  Rwanda               Sub-Saharan Africa            3.465
# 155                   Benin               Sub-Saharan Africa            3.340
# 156                   Syria  Middle East and Northern Africa            3.006
# 157                 Burundi               Sub-Saharan Africa            2.905
# 158                    Togo               Sub-Saharan Africa            2.839
#
# ...

# %%
# checking Outliers
sns.boxplot(y='Happiness Score', data=df)
plt.show()

# %%
# Boxplot of all column in one go to check outliers present in any columns.
df.plot(kind='box', subplots=True, layout=(3,3),figsize=(20,20))
# Out:
# Happiness Score                     AxesSubplot(0.125,0.653529;0.227941x0.226471)
# Economy (GDP per Capita)         AxesSubplot(0.398529,0.653529;0.227941x0.226471)
# Family                           AxesSubplot(0.672059,0.653529;0.227941x0.226471)
# Health (Life Expectancy)            AxesSubplot(0.125,0.381765;0.227941x0.226471)
# Freedom                          AxesSubplot(0.398529,0.381765;0.227941x0.226471)
# Trust (Government Corruption)    AxesSubplot(0.672059,0.381765;0.227941x0.226471)
# Generosity                              AxesSubplot(0.125,0.11;0.227941x0.226471)
# Dystopia Residual                    AxesSubplot(0.398529,0.11;0.227941x0.226471)
# dtype: object

# %% [markdown]
# From above box plot of each column we can notice that there are outliers present in Trust (Government Corruption) column. also there are few outliers presents in Generosity and Dystopia Residual column.

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Score                  float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
categorical_col=[]
numerical_col=[]
for i in df.columns:
    if df[i].dtype=='object':
        categorical_col.append(i)
    else:
        numerical_col.append(i)
print("Categorical columns are ", categorical_col)
print("Numerical Columns are ", numerical_col)
# Out:
# Categorical columns are  ['Country', 'Region']
# Numerical Columns are  ['Happiness Score', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
df1=df.iloc[:,2:]

# %%
from scipy.stats import zscore
z=np.abs(zscore(df1))
z
# Out:
#                 Happiness Score  Economy (GDP per Capita)    Family  \
# Happiness Rank
# 1                      1.937360                  1.369621  1.092524
# 2                      1.914581                  1.135226  1.229021
# 3                      1.884792                  1.192861  1.121403
# 4                      1.880411                  1.525130  1.043838
# 5                      1.797179                  1.194876  1.021850
# ...                         ...                       ...       ...
# 154                    1.674055                  1.552987  0.620726
# 155                    1.783571                  1.392303  2.350126
# 156                    2.076199                  0.455245  1.777621
# 157                    2.164688                  2.067566  2.046334
# 158                    2.222513                  1.586334  3.690946
#
#                 Health (Life Expectancy)   Freedom  \
# Happiness Rank
# 1                               1.263408  1.577438
# ...

# %%
np.where(z>3)
# Out:
# (array([ 63, 101, 128, 147, 155, 157], dtype=int64),
#  array([6, 6, 6, 2, 7, 2], dtype=int64))

# %% [markdown]
# most of the data are with in the limit as per 3 sigma rule. few of them are outliers. so to remove outliers

# %%
df2=df1[(z<3).all(axis=1)]
print("Shape of df1", df1.shape)
print("Shape of df2", df2.shape)
# Out:
# Shape of df1 (158, 8)
# Shape of df2 (152, 8)

# %% [markdown]
# Hence 6 rows droped

# %%
# Checking Correlation
df2.corr()
# Out:
#                                Happiness Score  Economy (GDP per Capita)  \
# Happiness Score                       1.000000                  0.781838
# Economy (GDP per Capita)              0.781838                  1.000000
# Family                                0.698908                  0.611836
# Health (Life Expectancy)              0.736941                  0.811640
# Freedom                               0.576208                  0.403143
# Trust (Government Corruption)         0.378502                  0.266358
# Generosity                            0.238398                  0.022257
# Dystopia Residual                     0.519878                  0.026051
#
#                                  Family  Health (Life Expectancy)   Freedom  \
# Happiness Score                0.698908                  0.736941  0.576208
# Economy (GDP per Capita)       0.611836                  0.811640  0.403143
# Family                         1.000000                  0.494073  0.452405
# ...

# %%
#fisualizing Correlation
sns.heatmap(df2.corr(), annot=True)
plt.show()

# %% [markdown]
# Observations:
# 1. There is strongly positive correlation in Economy, family, health, freedom and Dystopia Residual column w.r.t Happiness score.
# 2. very strongly correlation found in between Health and Economy column.

# %%
df2
# Out:
#                 Happiness Score  Economy (GDP per Capita)    Family  \
# Happiness Rank
# 1                         7.587                   1.39651  0.323368
# 2                         7.561                   1.30232  0.368316
# 3                         7.527                   1.32548  0.332878
# 4                         7.522                   1.45900  0.307336
# 5                         7.427                   1.32629  0.300096
# ...                         ...                       ...       ...
# 152                       3.587                   0.25812 -0.154053
# 153                       3.575                   0.31982 -0.899364
# 154                       3.465                   0.22208 -0.240796
# 155                       3.340                   0.28665 -0.810277
# 157                       2.905                   0.01530 -0.710240
#
#                 Health (Life Expectancy)  Freedom  \
# Happiness Rank
# 1                                0.94143  0.66557
# ...

# %%
#seperating label and input variables
x=df2.iloc[:,1:-1]
y=df2.iloc[:,0]
print("no of rows in x",x.shape[0])
print("no of rows in y", y.shape[0])
# Out:
# no of rows in x 152
# no of rows in y 152

# %%
# feature scaling with Standard Scalarization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.360381  1.231999                  1.257114  1.565391
# 1                    1.123133  1.397479                  1.283384  1.317619
# 2                    1.181469  1.267010                  0.983383  1.456385
# 3                    1.517782  1.172975                  1.026703  1.593401
# 4                    1.183509  1.146318                  1.110392  1.345897
# ..                        ...       ...                       ...       ...
# 147                 -1.507024 -0.525687                 -1.489540 -0.256813
# 148                 -1.351612 -3.269642                 -1.357982 -1.339403
# 149                 -1.597802 -0.845041                 -0.844496  1.070116
# 150                 -1.435162 -2.941659                 -1.293433  0.346257
# 151                 -2.118645 -2.573360                 -1.683353 -2.118001
#
#      Trust (Government Corruption)  Generosity
# ...

# %%
#checking the variance inflation factor
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['Features']=x.columns
vif['VIF Values']=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif
# Out:
#                         Features  VIF Values
# 0       Economy (GDP per Capita)    3.839547
# 1                         Family    1.786227
# 2       Health (Life Expectancy)    3.096538
# 3                        Freedom    1.890801
# 4  Trust (Government Corruption)    1.367391
# 5                     Generosity    1.267597

# %% [markdown]
# vif value for all column less than 10. Hence there multi colinearity is not present. and we do not need to drop any column.

# %% [markdown]
# ## Modeling

# %%
# importing libraries
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor, ExtraTreesRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error, r2_score

# %%
# Finding the best Random State
maxAccu=0
maxRS=0
for i in range(200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    rf=RandomForestRegressor()
    rf.fit(x_train,y_train)
    pred=rf.predict(x_test)
    accu=r2_score(y_test,pred)
    if accu>maxAccu:
        maxAccu=accu
        maxRS=i
print(f"Maximum r2score is {maxAccu} is at {maxRS}")
# Out:
# Maximum r2score is 0.8194181487588094 is at 117

# %%
#Spliting the dataset into train data and test data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRS)
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (106, 6) (46, 6) (106,) (46,)

# %%
# Linear Regression
lr=LinearRegression()
lr.fit(x_train,y_train)
pred_lr=lr.predict(x_test)
print(lr)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_lr))
print("Mean Squared Error=", mean_squared_error(y_test,pred_lr))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_lr)))
print("r squared score=",r2_score(y_test,pred_lr))
# Out:
# LinearRegression()
# Mean Absolute Error= 0.4108696383283124
# Mean Squared Error= 0.2674952270372857
# Root Mean Squared Error= 0.5171994074216304
# r squared score= 0.7996214578096543

# %%
# predicting through lasso regularisarion mathod
ls=Lasso()
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
print(ls)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_ls))
print("Mean Squared Error=", mean_squared_error(y_test,pred_ls))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_ls)))
print("r squared score=",r2_score(y_test,pred_ls))
# Out:
# Lasso()
# Mean Absolute Error= 1.013561525840853
# Mean Squared Error= 1.3416754126410453
# Root Mean Squared Error= 1.1583071322585583
# r squared score= -0.0050383562177336305

# %%
# Predicting through Ridge Regularisation
rg=Ridge()
rg.fit(x_train,y_train)
pred_rg=rg.predict(x_test)
print(rg)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_rg))
print("Mean Squared Error=", mean_squared_error(y_test,pred_rg))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_rg)))
print("r squared score=",r2_score(y_test,pred_rg))
# Out:
# Ridge()
# Mean Absolute Error= 0.41033612392704233
# Mean Squared Error= 0.26685709297011107
# Root Mean Squared Error= 0.5165821260652667
# r squared score= 0.8000994789523816

# %%
# Predicting through Gradient Boosting method
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
pred_gbr=gbr.predict(x_test)
print(gbr)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_gbr))
print("Mean Squared Error=", mean_squared_error(y_test,pred_gbr))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_gbr)))
print("r squared score=",r2_score(y_test,pred_gbr))
# Out:
# GradientBoostingRegressor()
# Mean Absolute Error= 0.3515533350474441
# Mean Squared Error= 0.21378330372362075
# Root Mean Squared Error= 0.4623670660023492
# r squared score= 0.8398566313902717

# %%
# Predicting through Random forest method
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
pred_rfr=rfr.predict(x_test)
print(rfr)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_rfr))
print("Mean Squared Error=", mean_squared_error(y_test,pred_rfr))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_rfr)))
print("r squared score=",r2_score(y_test,pred_rfr))
# Out:
# RandomForestRegressor()
# Mean Absolute Error= 0.3894941304347828
# Mean Squared Error= 0.25286617815434803
# Root Mean Squared Error= 0.5028580099335677
# r squared score= 0.8105799617099343

# %%
# Predicting through Extra Tree method
etr=ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr=etr.predict(x_test)
print(etr)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_etr))
print("Mean Squared Error=", mean_squared_error(y_test,pred_etr))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_etr)))
print("r squared score=",r2_score(y_test,pred_etr))
# Out:
# ExtraTreesRegressor()
# Mean Absolute Error= 0.40489021739130476
# Mean Squared Error= 0.25662148634565257
# Root Mean Squared Error= 0.5065782134534139
# r squared score= 0.8077668902799002

# %%
# Predicting through Ada Boost method
adr=AdaBoostRegressor()
adr.fit(x_train,y_train)
pred_adr=adr.predict(x_test)
print(adr)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_adr))
print("Mean Squared Error=", mean_squared_error(y_test,pred_adr))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_adr)))
print("r squared score=",r2_score(y_test,pred_adr))
# Out:
# AdaBoostRegressor()
# Mean Absolute Error= 0.3725839719929611
# Mean Squared Error= 0.23701225312155041
# Root Mean Squared Error= 0.4868390423143469
# r squared score= 0.8224560105697676

# %%
# Predicting through Decision Tree Regressor
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr=dtr.predict(x_test)
print(dtr)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_dtr))
print("Mean Squared Error=", mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_dtr)))
print("r squared score=",r2_score(y_test,pred_dtr))
# Out:
# DecisionTreeRegressor()
# Mean Absolute Error= 0.6432826086956521
# Mean Squared Error= 0.6724902391304347
# Root Mean Squared Error= 0.8200550220140321
# r squared score= 0.4962429227366718

# %%
# Predicting through Support vector machine regression
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
print(svr)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_svr))
print("Mean Squared Error=", mean_squared_error(y_test,pred_svr))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_svr)))
print("r squared score=",r2_score(y_test,pred_svr))
# Out:
# SVR()
# Mean Absolute Error= 0.39059648967317434
# Mean Squared Error= 0.23544708467780415
# Root Mean Squared Error= 0.48522889926075524
# r squared score= 0.8236284657739739

# %%
# Predicting through K nearest neighbor regression method
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
pred_knn=knn.predict(x_test)
print(knn)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred_knn))
print("Mean Squared Error=", mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error=",np.sqrt(mean_squared_error(y_test,pred_knn)))
print("r squared score=",r2_score(y_test,pred_knn))
# Out:
# KNeighborsRegressor()
# Mean Absolute Error= 0.34438260869565235
# Mean Squared Error= 0.2113826817391306
# Root Mean Squared Error= 0.45976372381814834
# r squared score= 0.8416549181818904

# %% [markdown]
# From all of the above method we have seen that Linear Regression Method gives us the best r2 score. hence linear regression model is the best performing model. Now we will look for Hyper Parameter Tuning to Get the best result out of Linear Regression model.

# %% [markdown]
# ## Hyper Parameter Tuning

# %%
#Best parameter for Ridge Regression
parameter={'alpha':[0.001,0.01,0.1],
           'fit_intercept':[True, False],
           'solver':['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga', 'lbfgs'],
           'random_state':[10,50,100]}
gsv=GridSearchCV(Ridge(),parameter,cv=5)
gsv.fit(x,y)
gsv.best_params_
# Out:
# {'alpha': 0.1, 'fit_intercept': True, 'random_state': 10, 'solver': 'lsqr'}

# %%
# looking for final model
final_model=Ridge(alpha=0.1,fit_intercept=True,random_state=10, solver='lsqr')
final_model.fit(x_train,y_train)
pred=final_model.predict(x_test)
print("Mean Absolute Error=",mean_absolute_error(y_test,pred))
print("Mean Squared Error =",mean_squared_error(y_test,pred))
print("Root Mean Squared Error =", np.sqrt(mean_squared_error(y_test,pred)))
print("R Squared Score", r2_score(y_test,pred))
# Out:
# Mean Absolute Error= 0.41081462523750195
# Mean Squared Error = 0.26742701749955133
# Root Mean Squared Error = 0.5171334619801269
# R Squared Score 0.7996725530306273

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(final_model, "happiness_score.pkl")
# Out:
# ['happiness_score.pkl']

# %%
load_model=joblib.load("happiness_score.pkl")
prediction=load_model.predict(x_test)
hpy_df=pd.DataFrame()
hpy_df['Actual Value']=y_test
hpy_df["Predicted Value"]= prediction
hpy_df
# Out:
#                 Actual Value  Predicted Value
# Happiness Rank
# 131                    4.292         3.423945
# 132                    4.271         5.815611
# 57                     5.828         5.706321
# 7                      7.378         7.032182
# 139                    3.989         4.334700
# 147                    3.681         3.934993
# 37                     6.302         6.871212
# 133                    4.252         4.471407
# 92                     5.013         4.551264
# 36                     6.329         6.446990
# 54                     5.855         5.780478
# 138                    3.995         4.389446
# 141                    3.931         4.749767
# 4                      7.522         7.156509
# 74                     5.399         5.711059
# 30                     6.574         5.932763
# 6                      7.406         6.849136
# 18                     6.940         7.111309
# 103                    4.839         5.425833
# ...
